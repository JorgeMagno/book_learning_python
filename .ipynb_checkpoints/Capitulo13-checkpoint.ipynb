# %%
print('Simple Calculator App')

def add(x, y):
    """" Adds two numbers """
    return x + y

def subtract(x, y):
    """ Subtracts two numbers """
    return x - y

def multiply(x, y):
    """ Multiples two numbers """
    return x * y

def divide(x, y):
    """Divides two numbers"""
    return x / y

def div(x, y):
    """Divides two numbers"""
    return x // y

def resto(x, y):
    """Divides two numbers"""
    return x % y

def potencia(x, y):
    """Divides two numbers"""
    return x ** y

def isnumber(value):
    try:
         float(value)
    except ValueError:
         return False
    return True

def check_if_user_has_finished():
    """
    Checks that the user wants to finish or not.
    Performs some verification of the input."""
    ok_to_finish = True
    user_input_accepted = False
    while not user_input_accepted:
        user_input = input('Do you want to finish (y/n): ')
        if user_input == 'y':
            user_input_accepted = True
        elif user_input == 'n':
            ok_to_finish = False
            user_input_accepted = True
        else:
            print('Response must be (y/n), please try again')
    return ok_to_finish

def get_operation_choice():
    input_ok = False
    while not input_ok:
        print('Menu Options are:')
        print('\t1. Add')
        print('\t2. Subtract')
        print('\t3. Multiply')
        print('\t4. Divide')
        print('\t5. Resto')
        print('\t6. Potência')
        print('-----------------')
        user_selection = input('Please make a selection: ')
        if user_selection in ('1', '2', '3', '4'):
            input_ok = True
        else:
            print('Invalid Input (must be 1 - 6)')
    print('-----------------')
    return user_selection

def get_operation_div():
    input_ok = False
    while not input_ok:
        print('Que tipo de divisão deseja?')
        print('\t1. Divisão Normal')
        print('\t2. Parte Inteira')
        print('-----------------')
        user_selection = input('Please make a selection: ')
        if user_selection in ('1', '2', '3', '4'):
            input_ok = True
        else:
            print('Invalid Input (must be 1 - 2)')
    print('-----------------')
    return user_selection

def get_integer_input(message):
    value_as_string = input(message)
    while not value_as_string.isdigit():
        if isnumber(value_as_string):
            return float(value_as_string)
            break
        else:
            print('The input must be an number')
            value_as_string = input(message)
    return float(value_as_string)

def get_numbers_from_user():
    num1 = get_integer_input('Input the first number: ')
    num2 = get_integer_input('Input the second number: ')
    return num1, num2




finished = False
while not finished:
    result = 0
    # Get the operation from the user
    menu_choice = get_operation_choice()
    # Get the numbers from the user
    n1, n2 = get_numbers_from_user()
    # Select the operation
    if menu_choice == '1':
        result = add(n1, n2)
    elif menu_choice == '2':
        result = subtract(n1, n2)
    elif menu_choice == '3':
        result = multiply(n1, n2)
    elif menu_choice == '4':
        tipodiv = get_operation_div()
        if tipodiv == '1':
            result = divide(n1, n2)
        elif tipodiv == '2':
            result = div(n1, n2)
    elif menu_choice == '5':
        result = resto(n1, n2)
    elif menu_choice == '6':
        result = potencia(n1, n2)
    print('Result:', result)
    print('=================')
    # Determine if the user has finished
    finished = check_if_user_has_finished()
print('Bye')
# Out:
# Simple Calculator App
# Menu Options are:
# 	1. Add
# 	2. Subtract
# 	3. Multiply
# 	4. Divide
# 	5. Resto
# 	6. Potência
# -----------------
# Please make a selection: 4
# -----------------
# Input the first number: 5
# Input the second number: 2
# Que tipo de divisão deseja?
# 	1. Divisão Normal
# 	2. Parte Inteira
# -----------------
# Please make a selection: 1
# -----------------
# Result: 2.5
# =================
# Do you want to finish (y/n): n
# Menu Options are:
# 	1. Add
# 	2. Subtract
# 	3. Multiply
# 	4. Divide
# 	5. Resto
# 	6. Potência
# -----------------
# Please make a selection: 4
# -----------------
# Input the first number: 5
# Input the second number: 2
# Que tipo de divisão deseja?
# 	1. Divisão Normal
# 	2. Parte Inteira
# -----------------
# Please make a selection: 2
# -----------------
# Result: 2.0
# =================
# Do you want to finish (y/n): y
# Bye
